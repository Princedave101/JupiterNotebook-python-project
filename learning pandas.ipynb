# %%
import pandas as pd 
print(pd.__version__)
# Out:
# 1.4.4

# %% [markdown]
# ## DataFrame
# A 2D data structure  containing 1D series.
# The keys in the dictionary are used as a column label while the values for the keys uses as the column values.
# A dataframe is thought of to consists of rows and columns.By default the rows label are scalar intergers running from
# 0 - len(df)-1

# %%
df = pd.DataFrame(
     {
        "Name": [
            "Braund, Mr. Owen Harris",
            "Allen, Mr. William Henry",
            "Bonnell, Miss. Elizabeth",
        ],
        "Age": [22, 35, 58],
        "Sex": ["male", "male", "female"],
    }
)

df
# Out:
#                        Name  Age     Sex
# 0   Braund, Mr. Owen Harris   22    male
# 1  Allen, Mr. William Henry   35    male
# 2  Bonnell, Miss. Elizabeth   58  female

# %% [markdown]
# ## series
# A selection of a column from a dataframe. its a 1D structure for scalar.
# A series is accessed the way a dictionary is accessed.
# A series could also be created from the Series class.

# %%
ages = df["Age"]
names = df["Name"]
print(ages)
print("----------------------------")
print(names)
# Out:
# 0    22
# 1    35
# 2    58
# Name: Age, dtype: int64
# ----------------------------
# 0     Braund, Mr. Owen Harris
# 1    Allen, Mr. William Henry
# 2    Bonnell, Miss. Elizabeth
# Name: Name, dtype: object

# %%
series = pd.Series([
    20, 
    10, 
    48
])
series
# Out:
# 0    20
# 1    10
# 2    48
# dtype: int64

# %% [markdown]
# ###### Max
# max() function returns the maximuim value in a series when perform on a numerical data

# %%
ages.max()
# Out:
# 58

# %% [markdown]
# ###### describe
# returns a numerical stats on a series of data

# %%
ages.describe()
# Out:
# count     3.000000
# mean     38.333333
# std      18.230012
# min      22.000000
# 25%      28.500000
# 50%      35.000000
# 75%      46.500000
# max      58.000000
# Name: Age, dtype: float64

# %% [markdown]
# ## How to read and write tabular data
# ### read_*()
# To read we use read_* to read csv, excel, html, etc with a tabular form .
# It reads data from a specific format to a pandas dataframe
# When displaying a DataFrame, the first and last 5 rows will be shown by default.

# %%
titanic = pd.read_csv("titanic.csv")
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
help(pd.read_csv)
# Out:
# Help on function read_csv in module pandas.io.parsers.readers:
#
# ...

# %%
help(pd.read_excel)
# Out:
# Help on function read_excel in module pandas.io.excel._base:
#
# read_excel(io, sheet_name: 'str | int | list[IntStrT] | None' = 0, header: 'int | Sequence[int] | None' = 0, names=None, index_col: 'int | Sequence[int] | None' = None, usecols=None, squeeze: 'bool | None' = None, dtype: 'DtypeArg | None' = None, engine: "Literal['xlrd', 'openpyxl', 'odf', 'pyxlsb'] | None" = None, converters=None, true_values: 'Iterable[Hashable] | None' = None, false_values: 'Iterable[Hashable] | None' = None, skiprows: 'Sequence[int] | int | Callable[[int], object] | None' = None, nrows: 'int | None' = None, na_values=None, keep_default_na: 'bool' = True, na_filter: 'bool' = True, verbose: 'bool' = False, parse_dates=False, date_parser=None, thousands: 'str | None' = None, decimal: 'str' = '.', comment: 'str | None' = None, skipfooter: 'int' = 0, convert_float: 'bool | None' = None, mangle_dupe_cols: 'bool' = True, storage_options: 'StorageOptions' = None) -> 'DataFrame | dict[IntStrT, DataFrame]'
# ...

# %% [markdown]
# ### head(N)
# returns the first N entries from the df

# %%
titanic.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %% [markdown]
# ### tail(N)
# returns the last n entries from the df.

# %%
titanic.tail(5)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %% [markdown]
# ### dtypes atrributes of dataframe or series
# returns the data type  of the columns(series)

# %%
titanic.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
titanic["Name"].dtype
# Out:
# dtype('O')

# %%
titanic["Parch"].dtype
# Out:
# dtype('int64')

# %% [markdown]
# ### info()
# returns  a technical summary of the dataframe
# 1. the numbers of entries on range 0- (N-1)
# 2. the list of columns header , its dtype(data type), and how many non-null values are in each columns
# 3. the storage capacity of the dataframe in memory

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# ### to_*()
# Whereas read_* functions are used to read data to pandas, the to_* methods are used to store data.

# %%
In [6]: titanic.to_excel("titanic.xlsx", sheet_name="passengers", index=False)
# index =false to not save the row label 
# sheet_name a parameter need to store the df in a sheet instead of the default Sheet1
# sheet_name : int|string

# %%
help(titanic.to_excel)
# Out:
# Help on method to_excel in module pandas.core.generic:
#
# to_excel(excel_writer, sheet_name: 'str' = 'Sheet1', na_rep: 'str' = '', float_format: 'str | None' = None, columns=None, header=True, index=True, index_label=None, startrow=0, startcol=0, engine=None, merge_cells=True, encoding=None, inf_rep='inf', verbose=True, freeze_panes=None, storage_options: 'StorageOptions' = None) -> 'None' method of pandas.core.frame.DataFrame instance
#     Write object to an Excel sheet.
#
#     To write a single object to an Excel .xlsx file it is only necessary to
#     specify a target file name. To write to multiple sheets it is necessary to
#     create an `ExcelWriter` object with a target file name, and specify a sheet
#     in the file to write to.
#
#     Multiple sheets may be written to by specifying unique `sheet_name`.
#     With all data written to the file it is necessary to save the changes.
#     Note that creating an `ExcelWriter` object with a file name that already
# ...

# %%
help(titanic.to_csv)
# Out:
# Help on method to_csv in module pandas.core.generic:
#
# to_csv(path_or_buf: 'FilePath | WriteBuffer[bytes] | WriteBuffer[str] | None' = None, sep: 'str' = ',', na_rep: 'str' = '', float_format: 'str | None' = None, columns: 'Sequence[Hashable] | None' = None, header: 'bool_t | list[str]' = True, index: 'bool_t' = True, index_label: 'IndexLabel | None' = None, mode: 'str' = 'w', encoding: 'str | None' = None, compression: 'CompressionOptions' = 'infer', quoting: 'int | None' = None, quotechar: 'str' = '"', line_terminator: 'str | None' = None, chunksize: 'int | None' = None, date_format: 'str | None' = None, doublequote: 'bool_t' = True, escapechar: 'str | None' = None, decimal: 'str' = '.', errors: 'str' = 'strict', storage_options: 'StorageOptions' = None) -> 'str | None' method of pandas.core.frame.DataFrame instance
#     Write object to a comma-separated values (csv) file.
#
#     Parameters
#     ----------
# ...

# %%
titanic = pd.read_excel("titanic.xlsx", sheet_name="passengers")
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
group1 = pd.read_excel("attendance.xlsx", sheet_name="Group1")
group1
# Out:
#      S/N    Matric No                           Names Meeting 1 Meeting 2  \
# 0    1.0  210805534.0              Okeke Prince David         ü         ü
# 1    2.0  190805083.0   Sogbesan Abdurrahman Olalekan       NaN         ü
# 2    3.0  190805087.0  Olaseni Precious Oluwatominsin       NaN         ü
# 3    4.0  190805037.0              Abdullah Olayiwola         ü         ü
# 4    5.0  190805028.0            Paul Carlos Ibironke         ü         ü
# 5    6.0  190805051.0                   Gali A Samuel         ü         ü
# 6    7.0  190806133.0               Eke Chinonso John       NaN         ü
# 7    8.0  190806026.0            Ganiyu Labake Salmat       NaN         ü
# 8    9.0  210806040.0     Fashina Oluwabukola Abiodun       NaN         ü
# 9   10.0  210806511.0         Temilore Kehinde Faluyi       NaN       NaN
# 10  11.0  210805519.0            Faluyi Gloria Adrian       NaN         ü
# 11  12.0  170401041.0                  Idowu Folajimi       NaN       NaN
# ...

# %%
group1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   S/N        19 non-null     float64
#  1   Matric No  19 non-null     float64
#  2   Names      19 non-null     object
#  3   Meeting 1  7 non-null      object
#  4   Meeting 2  13 non-null     object
#  5   Meeting 3  18 non-null     object
#  6   Meeting 4  12 non-null     object
#  7   Meeting 5  17 non-null     object
#  8   Logbook    19 non-null     object
# dtypes: float64(2), object(7)
# memory usage: 1.6+ KB

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic["Age"] > 20
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 886     True
# 887    False
# 888    False
# 889     True
# 890     True
# Name: Age, Length: 891, dtype: bool

# %%
test = {
    "age" :[10, 20, 80, 9, 93, 47]
}
for i in test["age"]:
    print(i>20)
# Out:
# False
# False
# True
# False
# True
# True

# %% [markdown]
# ## How do I select a subset of a DataFrame?

# %% [markdown]
# ### 1. How do I select specific columns from a DataFrame?

# %% [markdown]
# ###### To select a single column, use square brackets [ ] with the column name of the column of interest and have a look at the shape of the output:

# %%
ages = titanic["Age"].head()
ages
# Out:
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# Name: Age, dtype: float64

# %%
# shape attribute to check the shape of series and dataframe
ages.shape
# Out:
# (5,)

# %%
titanic.shape
# Out:
# (891, 12)

# %% [markdown]
# ###### To select multiple columns, use a list of column names within the selection brackets [ ].

# %%
age_sex = titanic[["Age", "Sex"]]
age_sex.head()
# Out:
#     Age     Sex
# 0  22.0    male
# 1  38.0  female
# 2  26.0  female
# 3  35.0  female
# 4  35.0    male

# %%
age_sex.shape
# Out:
# (891, 2)

# %%
type(age_sex)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### 2. How do I filter specific rows from a DataFrame?
#
# To select rows based on a conditional expression, use a condition inside the selection brackets [].
#
# The condition inside the selection brackets titanic["Age"] > 35 checks for which rows the Age column has a value larger than 35

# %%
titanic["Age"] > 35
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Age, Length: 891, dtype: bool

# %% [markdown]
# ######
# The output of the conditional expression (>, but also ==, !=, <, <=,… would work) is actually a pandas Series of boolean values (either True or False) with the same number of rows as the original DataFrame. Such a Series of boolean values can be used to filter the DataFrame by putting it in between the selection brackets []. Only rows for which the value is True will be selected.
#
# We know from before that the original Titanic DataFrame consists of 891 rows. Let’s have a look at the number of rows which satisfy the condition by checking the shape attribute of the resulting DataFrame above_35

# %%
above_35 = titanic[titanic["Age"] > 35]
above_35
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 6              7         0       1
# 11            12         1       1
# 13            14         0       3
# 15            16         1       2
# ..           ...       ...     ...
# 865          866         1       2
# 871          872         1       1
# 873          874         0       3
# 879          880         1       1
# 885          886         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 13                         Andersson, Mr. Anders Johan    male  39.0      1
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
above_35.shape
# Out:
# (217, 12)

# %%
# Similar to the conditional expression, the isin() conditional function returns a True for each row the values are in 
# the provided list.

class_2_3 = titanic[titanic["Pclass"].isin([2, 3])]
class_2_3.head(10)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 2             3         1       3
# 4             5         0       3
# 5             6         0       3
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 12           13         0       3
# 13           14         0       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 4                            Allen, Mr. William Henry    male  35.0      0
# 5                                    Moran, Mr. James    male   NaN      0
# 7                      Palsson, Master. Gosta Leonard    male   2.0      3
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# ...

# %%
#  you can separte multiple boolean condition using a parenthesis followed by |(or) or &(and)
class_23 = titanic[(titanic["Pclass"] == 2) | (titanic["Pclass"] == 3)]
class_23.head(10)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 2             3         1       3
# 4             5         0       3
# 5             6         0       3
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 12           13         0       3
# 13           14         0       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 4                            Allen, Mr. William Henry    male  35.0      0
# 5                                    Moran, Mr. James    male   NaN      0
# 7                      Palsson, Master. Gosta Leonard    male   2.0      3
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# ...

# %% [markdown]
# When combining multiple conditional statements, each condition must be surrounded by parentheses ().Moreover, you can
# not use or/and but need to use the or operator | and the and operator &.

# %% [markdown]
# #####  notna()
# The notna() conditional function returns a True for each row the values are not a Null value. As such, this can be combined with the selection brackets [] to filter the data table

# %%
age_no_na = titanic[titanic["Age"].notna()]
age_no_na
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ## 3. How do I select specific rows and columns from a DataFrame
# In this case, a subset of both rows and columns is made in one go and just using selection brackets [ ] is not sufficient anymore. The loc / iloc operators are required in front of the selection brackets [ ]. When using loc/iloc, the part before the comma is the rows you want, and the part after the comma is the columns you want to select.

# %%
adult_names = titanic.loc[titanic["Age"] > 35, "Name"]
adult_names.head()
# Out:
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...
# 6                               McCarthy, Mr. Timothy J
# 11                             Bonnell, Miss. Elizabeth
# 13                          Andersson, Mr. Anders Johan
# 15                     Hewlett, Mrs. (Mary D Kingcome)
# Name: Name, dtype: object

# %% [markdown]
# When using the column names, row labels or a condition expression, use the loc operator in front of the selection brackets []. For both the part before and after the comma, you can use a single label, a list of labels, a slice of labels, a conditional expression or a colon. Using a colon specifies you want to select all rows or columns.

# %%
young_adult = titanic.loc[(titanic["Age"]>18) & (titanic["Age"]<25), :]
young_adult.head(10)
# Out:
#     PassengerId  Survived  Pclass                            Name     Sex  \
# 0             1         0       3         Braund, Mr. Owen Harris    male
# 12           13         0       3  Saundercock, Mr. William Henry    male
# 27           28         0       1  Fortune, Mr. Charles Alexander    male
# 37           38         0       3        Cann, Mr. Ernest Charles    male
# 44           45         1       3   Devaney, Miss. Margaret Delia  female
# 51           52         0       3    Nosworthy, Mr. Richard Cater    male
# 56           57         1       2               Rugg, Miss. Emily  female
# 60           61         0       3           Sirayanian, Mr. Orsen    male
# 67           68         0       3        Crease, Mr. Ernest James    male
# 72           73         0       2            Hood, Mr. Ambrose Jr    male
#
#      Age  SibSp  Parch        Ticket      Fare        Cabin Embarked
# 0   22.0      1      0     A/5 21171    7.2500          NaN        S
# ...

# %%
young_adult.shape
# Out:
# (139, 12)

# %% [markdown]
# Again, a subset of both rows and columns is made in one go and just using selection brackets [] is not sufficient anymore.
# When specifically interested in certain rows and/or columns based on their position in the table, use the iloc operator
# in front of the selection brackets [].

# %%
titanic.iloc[9:25, 2:5]
# Out:
#     Pclass                                               Name     Sex
# 9        2                Nasser, Mrs. Nicholas (Adele Achem)  female
# 10       3                    Sandstrom, Miss. Marguerite Rut  female
# 11       1                           Bonnell, Miss. Elizabeth  female
# 12       3                     Saundercock, Mr. William Henry    male
# 13       3                        Andersson, Mr. Anders Johan    male
# 14       3               Vestrom, Miss. Hulda Amanda Adolfina  female
# 15       2                   Hewlett, Mrs. (Mary D Kingcome)   female
# 16       3                               Rice, Master. Eugene    male
# 17       2                       Williams, Mr. Charles Eugene    male
# 18       3  Vander Planke, Mrs. Julius (Emelia Maria Vande...  female
# 19       3                            Masselmani, Mrs. Fatima  female
# 20       2                               Fynney, Mr. Joseph J    male
# ...

# %%
group1["Names"].dropna()
# Out:
# 0                 Okeke Prince David
# 1      Sogbesan Abdurrahman Olalekan
# 2     Olaseni Precious Oluwatominsin
# 3                 Abdullah Olayiwola
# 4               Paul Carlos Ibironke
# 5                      Gali A Samuel
# 6                  Eke Chinonso John
# 7               Ganiyu Labake Salmat
# 8        Fashina Oluwabukola Abiodun
# 9            Temilore Kehinde Faluyi
# 10              Faluyi Gloria Adrian
# 11                    Idowu Folajimi
# 12         Adeiye Tajudeen Babatunde
# 13        Emeka-Ofoma Ugonna Francis
# 14         Sanni Olanrewaju Morolayo
# 15            Daodu Samuel Oluwafemi
# 16                 Oguntomi Damilola
# 17                Mgbo-Chigbo Sylvia
# 18    Abubakar Adedayo Adeniran-Obey
# Name: Names, dtype: object

# %%
titanic = pd.read_excel("titanic.xlsx", sheet_name="passengers", index_col =0)
titanic
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %% [markdown]
# ## How do I create plots in pandas?

# %%
air_quality = pd.read_csv("air_quality_no2.csv")
air_quality
# Out:
#                  datetime  station_antwerp  station_paris  station_london
# 0     2019-05-07 02:00:00              NaN            NaN            23.0
# 1     2019-05-07 03:00:00             50.5           25.0            19.0
# 2     2019-05-07 04:00:00             45.0           27.7            19.0
# 3     2019-05-07 05:00:00              NaN           50.4            16.0
# 4     2019-05-07 06:00:00              NaN           61.9             NaN
# ...                   ...              ...            ...             ...
# 1030  2019-06-20 22:00:00              NaN           21.4             NaN
# 1031  2019-06-20 23:00:00              NaN           24.9             NaN
# 1032  2019-06-21 00:00:00              NaN           26.5             NaN
# 1033  2019-06-21 01:00:00              NaN           21.8             NaN
# 1034  2019-06-21 02:00:00              NaN           20.0             NaN
#
# [1035 rows x 4 columns]

# %%
# we taking a look at the data
air_quality = pd.read_csv("air_quality_no2.csv", index_col=0, parse_dates=True)
air_quality.head()
# Out:
#                      station_antwerp  station_paris  station_london
# datetime
# 2019-05-07 02:00:00              NaN            NaN            23.0
# 2019-05-07 03:00:00             50.5           25.0            19.0
# 2019-05-07 04:00:00             45.0           27.7            19.0
# 2019-05-07 05:00:00              NaN           50.4            16.0
# 2019-05-07 06:00:00              NaN           61.9             NaN

# %% [markdown]
# The usage of the index_col and parse_dates parameters of the read_csv function to define the first (0th) column as index of the resulting DataFrame and convert the dates in the column to Timestamp objects, respectively

# %%
import pandas as pd
import matplotlib.pyplot as plt

air_quality.plot()
plt.show()

# %% [markdown]
# I want to plot only the columns of the data table with the data from Paris.
#
# To plot a specific column, use the selection method of the subset data tutorial in combination with the plot() method. Hence, the plot() method works on both Series and DataFrame.

# %%
air_quality["station_paris"].plot()
plt.show()

# %%
air_quality.plot.density()
plt.show()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
help(air_quality.plot)
# Out:
# Help on PlotAccessor in module pandas.plotting._core object:
#
# class PlotAccessor(pandas.core.base.PandasObject)
#  |  PlotAccessor(data)
#  |
#  |  Make plots of Series or DataFrame.
#  |
#  |  Uses the backend specified by the
#  |  option ``plotting.backend``. By default, matplotlib is used.
#  |
#  |  Parameters
#  |  ----------
#  |  data : Series or DataFrame
#  |      The object for which the method is called.
#  |  x : label or position, default None
#  |      Only used if data is a DataFrame.
#  |  y : label, position or list of label, positions, default None
#  |      Allows plotting of one column versus another. Only used if data is a
#  |      DataFrame.
#  |  kind : str
#  |      The kind of plot to produce:
#  |
#  |      - 'line' : line plot (default)
#  |      - 'bar' : vertical bar plot
#  |      - 'barh' : horizontal bar plot
#  |      - 'hist' : histogram
#  |      - 'box' : boxplot
#  |      - 'kde' : Kernel Density Estimation plot
# ...

# %%
help(dir)
# Out:
# Help on built-in function dir in module builtins:
#
# dir(...)
#     dir([object]) -> list of strings
#
#     If called without an argument, return the names in the current scope.
#     Else, return an alphabetized list of names comprising (some of) the attributes
#     of the given object, and of attributes reachable from it.
#     If the object supplies a method named __dir__, it will be used; otherwise
#     the default dir() logic is used and returns:
#       for a module object: the module's attributes.
#       for a class object:  its attributes, and recursively the attributes
#         of its bases.
#       for any other object: its attributes, its class's attributes, and
#         recursively the attributes of its class's base classes.

# %%
air_quality.plot.line()
# Out:
# <AxesSubplot:xlabel='datetime'>

# %%
[
    method_name
    for method_name in dir(air_quality.plot)
    if not method_name.startswith("_")
]
# Out:
# ['area',
#  'bar',
#  'barh',
#  'box',
#  'density',
#  'hexbin',
#  'hist',
#  'kde',
#  'line',
#  'pie',
#  'scatter']

# %%
help(air_quality.plot.bar)
# Out:
# Help on method bar in module pandas.plotting._core:
#
# bar(x=None, y=None, **kwargs) method of pandas.plotting._core.PlotAccessor instance
#     Vertical bar plot.
#
#     A bar plot is a plot that presents categorical data with
#     rectangular bars with lengths proportional to the values that they
#     represent. A bar plot shows comparisons among discrete categories. One
#     axis of the plot shows the specific categories being compared, and the
#     other axis represents a measured value.
#
#     Parameters
#     ----------
#     x : label or position, optional
#         Allows plotting of one column versus another. If not specified,
#         the index of the DataFrame is used.
#     y : label or position, optional
#         Allows plotting of one column versus another. If not specified,
#         all numerical columns are used.
#     color : str, array-like, or dict, optional
#         The color for each of the DataFrame's columns. Possible values are:
#
# ...

# %%
# air_quality.plot.bar(x=0, y=1)
# plt.show()
air_quality.plot(kind='bar', x=0, y=1)
# Out:
# <AxesSubplot:xlabel='station_antwerp'>

# %%
air_quality.plot(kind='hist', color=['green','yellow', 'red'])
# Out:
# <AxesSubplot:ylabel='Frequency'>
